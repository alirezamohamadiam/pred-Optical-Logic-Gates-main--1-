# %% [markdown]
# number genarator

# %%
import numpy as np
 
if __name__ == '__main__':
 
    start = 0   # inclusive
    end = 300    # exclusive
 
    n = 1
 
    x = np.random.uniform(low=start, high=end, size=(200)).astype(float)
    f = x.round((2))
    print(x)
# Out:
# [185.00024151  20.79738924  18.46491441 252.42058057  19.78176153
#  128.43485745   5.03331424 157.14078511 160.84701962 239.56643036
#  236.04434677 136.96634761 201.88951243 165.40724956 217.93326981
#  265.53198903 128.60237751  31.66927957  96.77915531 270.26470068
#  245.0275175   55.40941596 242.11757308  30.00942028  56.56260852
#  262.1579881  273.26033676  44.09899881  21.02147053   4.51627693
#  182.85990038  56.31238246 256.17152728 157.43196983  72.1520668
#  100.78265955  24.32483146 121.21488453 159.8154505   87.3713969
#   24.43285901  42.28752032 218.94625648 211.84459059 225.52240223
#   26.82800976  65.0030038  262.07946747  73.4048175  251.15779379
#  298.27887583 193.20553535  24.6156683   31.55457936  22.91291272
#  156.78055654 217.26300775 241.65128841 107.4256264  278.33519574
#  220.92159191  22.94052101 113.56495938 202.38755447 284.92616144
#   71.33591495   3.28600363 140.12832974 217.0879127  194.04529314
# ...

# %%
print([f])
# Out:
# [array([0.18, 0.08, 0.27, 0.19, 0.28, 0.12, 0.02, 0.2 , 0.06, 0.28, 0.03,
#        0.05, 0.07, 0.2 , 0.22, 0.13, 0.02, 0.21, 0.15, 0.21, 0.27, 0.19,
#        0.06, 0.29, 0.17, 0.2 , 0.11, 0.04, 0.28, 0.03, 0.15, 0.08, 0.05,
#        0.11, 0.12, 0.02, 0.11, 0.27, 0.27, 0.03, 0.06, 0.02, 0.08, 0.28,
#        0.29, 0.01, 0.03, 0.24, 0.2 , 0.12, 0.02, 0.14, 0.03, 0.01, 0.29,
#        0.21, 0.02, 0.28, 0.09, 0.02, 0.23, 0.  , 0.17, 0.18, 0.01, 0.2 ,
#        0.25, 0.22, 0.01, 0.24, 0.19, 0.27, 0.12, 0.18, 0.14, 0.02, 0.12,
#        0.15, 0.12, 0.23, 0.04, 0.07, 0.29, 0.29, 0.01, 0.13, 0.15, 0.14,
#        0.06, 0.23, 0.05, 0.19, 0.11, 0.24, 0.19, 0.19, 0.25, 0.03, 0.22,
#        0.12])]

# %%
import numpy as np
x= np.random.randn(0,10)
x
# Out:
# array([], shape=(0, 10), dtype=float64)

# %%
from numpy import random

x=random.rand(100) 
x1=x.round((2))
random.shuffle(x1)
print(x1)
# Out:
# [0.13 0.62 0.91 0.37 0.63 0.82 0.78 0.37 0.84 0.34 0.55 0.87 0.2  0.86
#  0.34 0.69 0.69 0.21 0.21 0.78 0.05 0.46 0.03 0.94 0.58 0.91 0.73 0.11
#  0.36 0.56 0.21 0.21 0.78 0.54 0.49 0.25 0.16 0.38 0.81 0.98 0.92 0.88
#  0.45 0.37 0.35 0.2  0.48 0.36 0.44 0.2  0.39 0.25 0.75 0.25 0.33 0.96
#  0.1  0.76 0.54 0.98 0.1  0.79 0.4  0.98 0.05 0.67 0.41 0.93 0.45 0.47
#  0.76 0.26 0.8  1.   0.15 0.08 0.34 0.11 0.06 0.47 0.84 0.12 0.54 1.
#  0.88 0.43 0.34 0.65 0.66 0.84 0.68 0.52 0.37 0.39 0.96 0.06 0.08 0.91
#  0.22 0.17]

# %%
import random
X3 = random.choices(x1, k=3)
print(X3)
# Out:
# [0.43, 0.05, 0.7]

# %%
x.range(300)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Alireza\OneDrive\Desktop\pred-Optical-Logic-Gates-main (1)\pred-Optical-Logic-Gates-main\number-gen.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alireza/OneDrive/Desktop/pred-Optical-Logic-Gates-main%20%281%29/pred-Optical-Logic-Gates-main/number-gen.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> x.range(300)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'range'

# %%
range(300)
# Out:
# range(0, 300)

# %%
number= list(range(301))
np.divide(number, 1000)
# Out:
# array([0.   , 0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008,
#        0.009, 0.01 , 0.011, 0.012, 0.013, 0.014, 0.015, 0.016, 0.017,
#        0.018, 0.019, 0.02 , 0.021, 0.022, 0.023, 0.024, 0.025, 0.026,
#        0.027, 0.028, 0.029, 0.03 , 0.031, 0.032, 0.033, 0.034, 0.035,
#        0.036, 0.037, 0.038, 0.039, 0.04 , 0.041, 0.042, 0.043, 0.044,
#        0.045, 0.046, 0.047, 0.048, 0.049, 0.05 , 0.051, 0.052, 0.053,
#        0.054, 0.055, 0.056, 0.057, 0.058, 0.059, 0.06 , 0.061, 0.062,
#        0.063, 0.064, 0.065, 0.066, 0.067, 0.068, 0.069, 0.07 , 0.071,
#        0.072, 0.073, 0.074, 0.075, 0.076, 0.077, 0.078, 0.079, 0.08 ,
#        0.081, 0.082, 0.083, 0.084, 0.085, 0.086, 0.087, 0.088, 0.089,
#        0.09 , 0.091, 0.092, 0.093, 0.094, 0.095, 0.096, 0.097, 0.098,
#        0.099, 0.1  , 0.101, 0.102, 0.103, 0.104, 0.105, 0.106, 0.107,
#        0.108, 0.109, 0.11 , 0.111, 0.112, 0.113, 0.114, 0.115, 0.116,
# ...

# %%
print([i])
# Out:
# [299]

# %%
print(number)
# Out:
# None

# %%
# printing first 6
# whole number
for i in range(6):
    print(i, end=" ")
print([i])
# Out:
# 0 1 2 3 4 5 [5]

# %%
m = [75
76
77
78
79
80
81
82
83
84
85
86
87]
# Out:
#   Input In [35]
#     76
#     ^
# SyntaxError: invalid syntax
